# %% [markdown]
# - # PREPROCESSING `eCO2mix`

# %% [markdown]
# ## Importation des modules

# %%
import sys
import os
import glob
import pandas as pd
# Ajoute le dossier parent au path pour importer data_preprocessing.py
sys.path.append(os.path.abspath(os.path.join('..')))

# %% [markdown]
# ## Importation des fonction de pré-traitement

# %% [markdown]
# - `fetch_eCO2mix_data` : télécharge la source de donnée `eCO2mix`
# - `convert_all_xls_eCO2mix_data` : converti les fichiers `.xls` en `.csv`
# - `concat_eCO2mix_annual_data` : concatène les données de consommation en un seul Dataframe
# - `concat_eCO2mix_tempo_data` : concatène les donnée du calendrier TEMPO en un seul Dataframe
# - `preprocess_annual_data` : Premier traitement du nettoyage de donnée sur les données de consommation
# - `preprocess_tempo_data` : Premier traitement sur le nettoyage de donnée sur les données TEMPO
# - `merge_eCO2mix_data`: jointure gauche des données de consommation et TEMPO sur la date
# - `preprocess_eCO2mix_data` : Deuxième traitement de nettoyage sur la donnée jointe de consommation et TEMPO
# - `preprocess_eCO2mix_data_engineered` : Dernier traitement de nettoyage sur les données jointe de consommation et TEMPO après application du feature engineering
#
# **Chaque fonctions de traitement teste la conformité de la source de donnée.**

# %%
from src.data_preprocessing import (
    fetch_eCO2mix_data,
    convert_all_xls_eCO2mix_data,
    concat_eCO2mix_annual_data,
    concat_eCO2mix_tempo_data,
    preprocess_annual_data,
    preprocess_tempo_data,
    merge_eCO2mix_data,
    preprocess_eCO2mix_data,
    preprocess_eCO2mix_data_engineered
    )

# %% [markdown]
# ## Donnée de `eCO2mix`

# %% [markdown]
# ### Téléchargement des données

# %%
fetch_eCO2mix_data()
# Out:
# 🌐 Chargement de https://www.rte-france.com/eco2mix/telecharger-les-indicateurs
# 🔗 24 liens détectés (ZIP + Tempo).
# ⬇️  Téléchargement ZIP : eCO2mix_RTE_En-cours-TR.zip
# ✅ Contenu de eCO2mix_RTE_En-cours-TR.zip extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : eCO2mix_RTE_En-cours-Consolide.zip
# ✅ Contenu de eCO2mix_RTE_En-cours-Consolide.zip extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : eCO2mix_RTE_Annuel-Definitif_2012.zip
# ✅ Contenu de eCO2mix_RTE_Annuel-Definitif_2012.zip extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : eCO2mix_RTE_Annuel-Definitif_2013.zip
# ✅ Contenu de eCO2mix_RTE_Annuel-Definitif_2013.zip extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : eCO2mix_RTE_Annuel-Definitif_2014.zip
# ✅ Contenu de eCO2mix_RTE_Annuel-Definitif_2014.zip extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : eCO2mix_RTE_Annuel-Definitif_2015.zip
# ✅ Contenu de eCO2mix_RTE_Annuel-Definitif_2015.zip extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : eCO2mix_RTE_Annuel-Definitif_2016.zip
# ✅ Contenu de eCO2mix_RTE_Annuel-Definitif_2016.zip extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : eCO2mix_RTE_Annuel-Definitif_2017.zip
# ✅ Contenu de eCO2mix_RTE_Annuel-Definitif_2017.zip extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : eCO2mix_RTE_Annuel-Definitif_2018.zip
# ✅ Contenu de eCO2mix_RTE_Annuel-Definitif_2018.zip extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : eCO2mix_RTE_Annuel-Definitif_2019.zip
# ✅ Contenu de eCO2mix_RTE_Annuel-Definitif_2019.zip extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : eCO2mix_RTE_Annuel-Definitif_2020.zip
# ✅ Contenu de eCO2mix_RTE_Annuel-Definitif_2020.zip extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : eCO2mix_RTE_Annuel-Definitif_2021.zip
# ✅ Contenu de eCO2mix_RTE_Annuel-Definitif_2021.zip extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : eCO2mix_RTE_Annuel-Definitif_2022.zip
# ✅ Contenu de eCO2mix_RTE_Annuel-Definitif_2022.zip extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : downloadCalendrierTempo
# ✅ Contenu de downloadCalendrierTempo extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : downloadCalendrierTempo
# ✅ Contenu de downloadCalendrierTempo extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : downloadCalendrierTempo
# ✅ Contenu de downloadCalendrierTempo extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : downloadCalendrierTempo
# ✅ Contenu de downloadCalendrierTempo extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : downloadCalendrierTempo
# ✅ Contenu de downloadCalendrierTempo extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : downloadCalendrierTempo
# ✅ Contenu de downloadCalendrierTempo extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : downloadCalendrierTempo
# ✅ Contenu de downloadCalendrierTempo extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : downloadCalendrierTempo
# ✅ Contenu de downloadCalendrierTempo extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : downloadCalendrierTempo
# ✅ Contenu de downloadCalendrierTempo extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : downloadCalendrierTempo
# ✅ Contenu de downloadCalendrierTempo extrait dans ../data/external/
# ⬇️  Téléchargement ZIP : downloadCalendrierTempo
# ✅ Contenu de downloadCalendrierTempo extrait dans ../data/external/

# %% [markdown]
# ### Définition des répertoires de données

# %%
xls_folder = os.path.join('..', 'data', 'external')

# %%
# Dossiers contenant les fichiers source
eco2mix_folder = os.path.join("..","data", "raw")

# %% [markdown]
# ### Conversion des XLS en CSV

# %%
convert_all_xls_eCO2mix_data(xls_folder, eco2mix_folder)
# Out:
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2012.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2013.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2014.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2015.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2016.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2017.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2018.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2019.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2020.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2021.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2022.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_En-cours-Consolide.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_En-cours-TR.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_tempo_2014-2015.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_tempo_2015-2016.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_tempo_2016-2017.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_tempo_2017-2018.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_tempo_2018-2019.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_tempo_2019-2020.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_tempo_2020-2021.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_tempo_2021-2022.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_tempo_2022-2023.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_tempo_2023-2024.csv
# ✅ Fichier converti et nettoyé : ..\data\raw\eCO2mix_RTE_tempo_2024-2025.csv

# %% [markdown]
# ### Chargement de toute la consommation horaire

# %% [markdown]
# - Concaténation des donnée de consommation venant de plusieurs sources de données

# %%
df_annual = concat_eCO2mix_annual_data(eco2mix_folder)
df_annual
# Out:
# Lecture des fichiers annuels :
#   - ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2012.csv
#   - ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2013.csv
#   - ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2014.csv
#   - ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2015.csv
#   - ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2016.csv
#   - ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2017.csv
#   - ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2018.csv
#   - ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2019.csv
#   - ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2020.csv
#   - ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2021.csv
#   - ..\data\raw\eCO2mix_RTE_Annuel-Definitif_2022.csv
#   - ..\data\raw\eCO2mix_RTE_En-cours-Consolide.csv
#   - ..\data\raw\eCO2mix_RTE_En-cours-TR.csv
#        Périmètre               Nature        Date Heures Consommation  \
# 0         France  Données définitives  2012-01-01  00:00        58315
# 1         France  Données définitives  2012-01-01  00:15          NaN
# 2         France  Données définitives  2012-01-01  00:30        58315
# 3         France  Données définitives  2012-01-01  00:45          NaN
# 4         France  Données définitives  2012-01-01  01:00        56231
# ...          ...                  ...         ...    ...          ...
# 467131    France   Données temps réel  2025-04-27  22:45          NaN
# 467132    France   Données temps réel  2025-04-27  23:00          NaN
# 467133    France   Données temps réel  2025-04-27  23:15          NaN
# 467134    France   Données temps réel  2025-04-27  23:30          NaN
# 467135    France   Données temps réel  2025-04-27  23:45          NaN
#
#        Prévision J-1 Prévision J Fioul Charbon   Gaz  ...  \
# 0              58200       58200   492      25  3816  ...
# 1              57700       57550   NaN     NaN   NaN  ...
# 2              57200       56900   492      25  3816  ...
# 3              56200       56000   NaN     NaN   NaN  ...
# 4              55200       55100   492      25  3834  ...
# ...              ...         ...   ...     ...   ...  ...
# 467131            ND         NaN   NaN     NaN   NaN  ...
# 467132            ND         NaN   NaN     NaN   NaN  ...
# 467133            ND         NaN   NaN     NaN   NaN  ...
# 467134            ND         NaN   NaN     NaN   NaN  ...
# 467135            ND         NaN   NaN     NaN   NaN  ...
#
#        Hydraulique - Fil de l?eau + éclusée Hydraulique - Lacs  \
# 0                                        ND                 ND
# 1                                       NaN                NaN
# 2                                        ND                 ND
# 3                                       NaN                NaN
# 4                                        ND                 ND
# ...                                     ...                ...
# 467131                                  NaN                NaN
# 467132                                  NaN                NaN
# 467133                                  NaN                NaN
# 467134                                  NaN                NaN
# 467135                                  NaN                NaN
#
#        Hydraulique - STEP turbinage Bioénergies - Déchets  \
# 0                                ND                    ND
# 1                               NaN                   NaN
# 2                                ND                    ND
# 3                               NaN                   NaN
# 4                                ND                    ND
# ...                             ...                   ...
# 467131                          NaN                   NaN
# 467132                          NaN                   NaN
# 467133                          NaN                   NaN
# 467134                          NaN                   NaN
# 467135                          NaN                   NaN
#
#        Bioénergies - Biomasse Bioénergies - Biogaz  Stockage batterie  \
# 0                          ND                   ND                NaN
# 1                         NaN                  NaN                NaN
# 2                          ND                   ND                NaN
# 3                         NaN                  NaN                NaN
# 4                          ND                   ND                NaN
# ...                       ...                  ...                ...
# 467131                    NaN                  NaN                NaN
# 467132                    NaN                  NaN                NaN
# 467133                    NaN                  NaN                NaN
# 467134                    NaN                  NaN                NaN
# 467135                    NaN                  NaN                NaN
#
#        Déstockage batterie Eolien terrestre Eolien offshore
# 0                      NaN              NaN             NaN
# 1                      NaN              NaN             NaN
# 2                      NaN              NaN             NaN
# 3                      NaN              NaN             NaN
# 4                      NaN              NaN             NaN
# ...                    ...              ...             ...
# 467131                 NaN              NaN             NaN
# 467132                 NaN              NaN             NaN
# 467133                 NaN              NaN             NaN
# 467134                 NaN              NaN             NaN
# 467135                 NaN              NaN             NaN
#
# [467136 rows x 40 columns]

# %% [markdown]
# ### Premier passage de traitement des consommations horaires

# %%
df_annual = preprocess_annual_data(df_annual)
df_annual
# Out:
#              Date Heures Consommation            Datetime
# 0      2012-01-01  00:00        58315 2012-01-01 00:00:00
# 2      2012-01-01  00:30        58315 2012-01-01 00:30:00
# 4      2012-01-01  01:00        56231 2012-01-01 01:00:00
# 6      2012-01-01  01:30        56075 2012-01-01 01:30:00
# 8      2012-01-01  02:00        55532 2012-01-01 02:00:00
# ...           ...    ...          ...                 ...
# 466880 2025-04-25  08:00        50734 2025-04-25 08:00:00
# 466881 2025-04-25  08:15        51745 2025-04-25 08:15:00
# 466882 2025-04-25  08:30        52209 2025-04-25 08:30:00
# 466883 2025-04-25  08:45        52312 2025-04-25 08:45:00
# 466884 2025-04-25  09:00        52630 2025-04-25 09:00:00
#
# [272533 rows x 4 columns]

# %% [markdown]
# ### Chargement de toute la donnée TEMPO

# %% [markdown]
# - Concaténation des donnée du calendrier TEMPO venant de plusieurs sources de données

# %%
df_tempo = concat_eCO2mix_tempo_data(eco2mix_folder)
df_tempo
# Out:
# Lecture des fichiers tempo :
#   - ..\data\raw\eCO2mix_RTE_tempo_2014-2015.csv
#   - ..\data\raw\eCO2mix_RTE_tempo_2015-2016.csv
#   - ..\data\raw\eCO2mix_RTE_tempo_2016-2017.csv
#   - ..\data\raw\eCO2mix_RTE_tempo_2017-2018.csv
#   - ..\data\raw\eCO2mix_RTE_tempo_2018-2019.csv
#   - ..\data\raw\eCO2mix_RTE_tempo_2019-2020.csv
#   - ..\data\raw\eCO2mix_RTE_tempo_2020-2021.csv
#   - ..\data\raw\eCO2mix_RTE_tempo_2021-2022.csv
#   - ..\data\raw\eCO2mix_RTE_tempo_2022-2023.csv
#   - ..\data\raw\eCO2mix_RTE_tempo_2023-2024.csv
#   - ..\data\raw\eCO2mix_RTE_tempo_2024-2025.csv
#             Date Type de jour TEMPO
# 0     2014-09-01               BLEU
# 1     2014-09-02               BLEU
# 2     2014-09-03               BLEU
# 3     2014-09-04               BLEU
# 4     2014-09-05               BLEU
# ...          ...                ...
# 3886  2025-04-22               BLEU
# 3887  2025-04-23               BLEU
# 3888  2025-04-24               BLEU
# 3889  2025-04-25               BLEU
# 3890  2025-04-26               BLEU
#
# [3891 rows x 2 columns]

# %% [markdown]
# ### Premier passage de traitement des données TEMPO

# %%
df_tempo = preprocess_tempo_data(df_tempo)
df_tempo
# Out:
#            Date  Type de jour TEMPO_BLANC  Type de jour TEMPO_BLEU  \
# 0    2014-09-01                     False                     True
# 1    2014-09-02                     False                     True
# 2    2014-09-03                     False                     True
# 3    2014-09-04                     False                     True
# 4    2014-09-05                     False                     True
# ...         ...                       ...                      ...
# 3886 2025-04-22                     False                     True
# 3887 2025-04-23                     False                     True
# 3888 2025-04-24                     False                     True
# 3889 2025-04-25                     False                     True
# 3890 2025-04-26                     False                     True
#
#       Type de jour TEMPO_ROUGE
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 3886                     False
# 3887                     False
# 3888                     False
# 3889                     False
# 3890                     False
#
# [3891 rows x 4 columns]

# %% [markdown]
# ### Jointure gauche des données de consommation horaire et TEMPO

# %%
df_merged = merge_eCO2mix_data(df_annual, df_tempo)
df_merged
# Out:
#              Date Heures Consommation            Datetime  \
# 0      2012-01-01  00:00        58315 2012-01-01 00:00:00
# 1      2012-01-01  00:30        58315 2012-01-01 00:30:00
# 2      2012-01-01  01:00        56231 2012-01-01 01:00:00
# 3      2012-01-01  01:30        56075 2012-01-01 01:30:00
# 4      2012-01-01  02:00        55532 2012-01-01 02:00:00
# ...           ...    ...          ...                 ...
# 272528 2025-04-25  08:00        50734 2025-04-25 08:00:00
# 272529 2025-04-25  08:15        51745 2025-04-25 08:15:00
# 272530 2025-04-25  08:30        52209 2025-04-25 08:30:00
# 272531 2025-04-25  08:45        52312 2025-04-25 08:45:00
# 272532 2025-04-25  09:00        52630 2025-04-25 09:00:00
#
#        Type de jour TEMPO_BLANC Type de jour TEMPO_BLEU  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ...                         ...                     ...
# 272528                    False                    True
# 272529                    False                    True
# 272530                    False                    True
# 272531                    False                    True
# 272532                    False                    True
#
#        Type de jour TEMPO_ROUGE
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 272528                    False
# 272529                    False
# 272530                    False
# 272531                    False
# 272532                    False
#
# [272533 rows x 7 columns]

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# - `create_date_features` : décompose la colonne Date en plusieurs feature distincte caractérisant des information sur le temps (année, mois, jour, jour de la semaine...)
# - `create_lag_features` : Ajout des variables de décalage sur la `Consommation` (*N-1*, *N-2*, *N-3*)
# - `create_rolling_features` : Ajout de la moyenne mobile (*moyenne sur les 3 dernières consommation*)
# - `create_hour_features` : Transformation de l'horaire en features encoder cycliquement par sinus et cosinus

# %%
from src.feature_engineering import(
    create_date_features,
    create_lag_features,
    create_rolling_features,
    create_hour_features
)

# %% [markdown]
# ### Applications du features engineering

# %%
df_merged = create_date_features(df_merged)
df_merged = create_lag_features(df_merged, 'Consommation')
df_merged = create_rolling_features(df_merged, 'Consommation')
df_merged = create_hour_features(df_merged)
df_merged
# Out:
#              Date Heures Consommation            Datetime  \
# 0      2012-01-01  00:00        58315 2012-01-01 00:00:00
# 1      2012-01-01  00:30        58315 2012-01-01 00:30:00
# 2      2012-01-01  01:00        56231 2012-01-01 01:00:00
# 3      2012-01-01  01:30        56075 2012-01-01 01:30:00
# 4      2012-01-01  02:00        55532 2012-01-01 02:00:00
# ...           ...    ...          ...                 ...
# 272528 2025-04-25  08:00        50734 2025-04-25 08:00:00
# 272529 2025-04-25  08:15        51745 2025-04-25 08:15:00
# 272530 2025-04-25  08:30        52209 2025-04-25 08:30:00
# 272531 2025-04-25  08:45        52312 2025-04-25 08:45:00
# 272532 2025-04-25  09:00        52630 2025-04-25 09:00:00
#
#        Type de jour TEMPO_BLANC Type de jour TEMPO_BLEU  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ...                         ...                     ...
# 272528                    False                    True
# 272529                    False                    True
# 272530                    False                    True
# 272531                    False                    True
# 272532                    False                    True
#
#        Type de jour TEMPO_ROUGE  year  month  day  ...  dayofyear  is_weekend  \
# 0                           NaN  2012      1    1  ...          1        True
# 1                           NaN  2012      1    1  ...          1        True
# 2                           NaN  2012      1    1  ...          1        True
# 3                           NaN  2012      1    1  ...          1        True
# 4                           NaN  2012      1    1  ...          1        True
# ...                         ...   ...    ...  ...  ...        ...         ...
# 272528                    False  2025      4   25  ...        115       False
# 272529                    False  2025      4   25  ...        115       False
# 272530                    False  2025      4   25  ...        115       False
# 272531                    False  2025      4   25  ...        115       False
# 272532                    False  2025      4   25  ...        115       False
#
#         is_end_of_month  Consommation_lag_1  Consommation_lag_2  \
# 0                 False                None                None
# 1                 False               58315                None
# 2                 False               58315               58315
# 3                 False               56231               58315
# 4                 False               56075               56231
# ...                 ...                 ...                 ...
# 272528            False               50248               49795
# 272529            False               50734               50248
# 272530            False               51745               50734
# 272531            False               52209               51745
# 272532            False               52312               52209
#
#         Consommation_lag_3 Consommation_rolling_mean_3 hour_transformed  \
# 0                     None                         NaN                0
# 1                     None                58315.000000                0
# 2                     None                58315.000000                1
# 3                    58315                57620.333333                1
# 4                    58315                56873.666667                2
# ...                    ...                         ...              ...
# 272528               48695                49579.333333                8
# 272529               49795                50259.000000                8
# 272530               50248                50909.000000                8
# 272531               50734                51562.666667                8
# 272532               51745                52088.666667                9
#
#         hour_sin  hour_cos
# 0       0.000000  1.000000
# 1       0.000000  1.000000
# 2       0.258819  0.965926
# 3       0.258819  0.965926
# 4       0.500000  0.866025
# ...          ...       ...
# 272528  0.866025 -0.500000
# 272529  0.866025 -0.500000
# 272530  0.866025 -0.500000
# 272531  0.866025 -0.500000
# 272532  0.707107 -0.707107
#
# [272533 rows x 23 columns]

# %% [markdown]
# ### Dernier traitement sur le nettoyage et conformité de la donnée

# %%
df_merged = preprocess_eCO2mix_data(df_merged)
df_merged = preprocess_eCO2mix_data_engineered(df_merged)
df_merged
# Out:
#                           Date Heures Consommation Type de jour TEMPO_BLANC  \
# Datetime
# 2014-09-01 00:00:00 2014-09-01  00:00        43320                    False
# 2014-09-01 00:30:00 2014-09-01  00:30        41174                    False
# 2014-09-01 01:00:00 2014-09-01  01:00        38430                    False
# 2014-09-01 01:30:00 2014-09-01  01:30        37800                    False
# 2014-09-01 02:00:00 2014-09-01  02:00        37137                    False
# ...                        ...    ...          ...                      ...
# 2025-04-25 08:00:00 2025-04-25  08:00        50734                    False
# 2025-04-25 08:15:00 2025-04-25  08:15        51745                    False
# 2025-04-25 08:30:00 2025-04-25  08:30        52209                    False
# 2025-04-25 08:45:00 2025-04-25  08:45        52312                    False
# 2025-04-25 09:00:00 2025-04-25  09:00        52630                    False
#
#                     Type de jour TEMPO_BLEU Type de jour TEMPO_ROUGE  year  \
# Datetime
# 2014-09-01 00:00:00                    True                    False  2014
# 2014-09-01 00:30:00                    True                    False  2014
# 2014-09-01 01:00:00                    True                    False  2014
# 2014-09-01 01:30:00                    True                    False  2014
# 2014-09-01 02:00:00                    True                    False  2014
# ...                                     ...                      ...   ...
# 2025-04-25 08:00:00                    True                    False  2025
# 2025-04-25 08:15:00                    True                    False  2025
# 2025-04-25 08:30:00                    True                    False  2025
# 2025-04-25 08:45:00                    True                    False  2025
# 2025-04-25 09:00:00                    True                    False  2025
#
#                      month  day  weekday  ...  dayofyear  is_weekend  \
# Datetime                                  ...
# 2014-09-01 00:00:00      9    1        0  ...        244       False
# 2014-09-01 00:30:00      9    1        0  ...        244       False
# 2014-09-01 01:00:00      9    1        0  ...        244       False
# 2014-09-01 01:30:00      9    1        0  ...        244       False
# 2014-09-01 02:00:00      9    1        0  ...        244       False
# ...                    ...  ...      ...  ...        ...         ...
# 2025-04-25 08:00:00      4   25        4  ...        115       False
# 2025-04-25 08:15:00      4   25        4  ...        115       False
# 2025-04-25 08:30:00      4   25        4  ...        115       False
# 2025-04-25 08:45:00      4   25        4  ...        115       False
# 2025-04-25 09:00:00      4   25        4  ...        115       False
#
#                      is_end_of_month  Consommation_lag_1  Consommation_lag_2  \
# Datetime
# 2014-09-01 00:00:00            False               43938               44567
# 2014-09-01 00:30:00            False               43320               43938
# 2014-09-01 01:00:00            False               41174               43320
# 2014-09-01 01:30:00            False               38430               41174
# 2014-09-01 02:00:00            False               37800               38430
# ...                              ...                 ...                 ...
# 2025-04-25 08:00:00            False               50248               49795
# 2025-04-25 08:15:00            False               50734               50248
# 2025-04-25 08:30:00            False               51745               50734
# 2025-04-25 08:45:00            False               52209               51745
# 2025-04-25 09:00:00            False               52312               52209
#
#                     Consommation_lag_3 Consommation_rolling_mean_3  \
# Datetime
# 2014-09-01 00:00:00              42056                43520.333333
# 2014-09-01 00:30:00              44567                43941.666667
# 2014-09-01 01:00:00              43938                42810.666667
# 2014-09-01 01:30:00              43320                40974.666667
# 2014-09-01 02:00:00              41174                39134.666667
# ...                                ...                         ...
# 2025-04-25 08:00:00              48695                49579.333333
# 2025-04-25 08:15:00              49795                50259.000000
# 2025-04-25 08:30:00              50248                50909.000000
# 2025-04-25 08:45:00              50734                51562.666667
# 2025-04-25 09:00:00              51745                52088.666667
#
#                     hour_transformed  hour_sin  hour_cos
# Datetime
# 2014-09-01 00:00:00                0  0.000000  1.000000
# 2014-09-01 00:30:00                0  0.000000  1.000000
# 2014-09-01 01:00:00                1  0.258819  0.965926
# 2014-09-01 01:30:00                1  0.258819  0.965926
# 2014-09-01 02:00:00                2  0.500000  0.866025
# ...                              ...       ...       ...
# 2025-04-25 08:00:00                8  0.866025 -0.500000
# 2025-04-25 08:15:00                8  0.866025 -0.500000
# 2025-04-25 08:30:00                8  0.866025 -0.500000
# 2025-04-25 08:45:00                8  0.866025 -0.500000
# 2025-04-25 09:00:00                9  0.707107 -0.707107
#
# [225781 rows x 22 columns]

# %% [markdown]
# ## Exportation de la donnée nettoyé, transformé

# %%
df_merged.to_csv(os.path.join('..', 'data', 'processed', 'eco2mix_data.csv'), index=False)

# %% [markdown]
# ## Donnée `meteo.gouv.fr`

# %%
from src.data_preprocessing import load_data

# %%
wheather_folder = os.path.join("..", "data", "raw")

# %%
weather_pattern = os.path.join(wheather_folder,"H_02_*.csv")
weather_files = glob.glob(weather_pattern)
list_df_weather = []

for file in weather_files:
    print (" -", file)
    try:
        df = load_data(file, encoding="utf-8", sep=";")
        list_df_weather.append(df)
    except Exception as e:
        print(f"Erreur lors du chargement du fichier {file}: {e}")
df_weather = pd.concat(list_df_weather, ignore_index=True, axis=0)
df_weather
# Out:
#  - ..\data\raw\H_02_2010-2019.csv
#  - ..\data\raw\H_02_latest-2024-2025.csv
#  - ..\data\raw\H_02_previous-2020-2023.csv
#         NUM_POSTE NOM_USUEL        LAT       LON ALTI  AAAAMMJJHH  RR1 QRR1  \
# 0        02031001  AUBENTON  49.834000  4.200500  177  2010120106  NaN  NaN
# 1        02031001  AUBENTON  49.834000  4.200500  177  2010120206  NaN  NaN
# 2        02031001  AUBENTON  49.834000  4.200500  177  2010120306  NaN  NaN
# 3        02031001  AUBENTON  49.834000  4.200500  177  2010120406  NaN  NaN
# 4        02031001  AUBENTON  49.834000  4.200500  177  2010120506  NaN  NaN
# ...           ...       ...        ...       ...  ...         ...  ...  ...
# 1224904  02738001  TERGNIER  49.663833  3.320667   59  2023123119  0.0    1
# 1224905  02738001  TERGNIER  49.663833  3.320667   59  2023123120  0.0    1
# 1224906  02738001  TERGNIER  49.663833  3.320667   59  2023123121  0.0    1
# 1224907  02738001  TERGNIER  49.663833  3.320667   59  2023123122  0.0    1
# 1224908  02738001  TERGNIER  49.663833  3.320667   59  2023123123  0.0    1
#
#         DRR1 QDRR1  ...  INS QINS INS2 QINS2 TLAGON QTLAGON TVEGETAUX  \
# 0        NaN   NaN  ...  NaN  NaN  NaN   NaN    NaN     NaN       NaN
# 1        NaN   NaN  ...  NaN  NaN  NaN   NaN    NaN     NaN       NaN
# 2        NaN   NaN  ...  NaN  NaN  NaN   NaN    NaN     NaN       NaN
# 3        NaN   NaN  ...  NaN  NaN  NaN   NaN    NaN     NaN       NaN
# 4        NaN   NaN  ...  NaN  NaN  NaN   NaN    NaN     NaN       NaN
# ...      ...   ...  ...  ...  ...  ...   ...    ...     ...       ...
# 1224904  NaN   NaN  ...  NaN  NaN  NaN   NaN    NaN     NaN       NaN
# 1224905  NaN   NaN  ...  NaN  NaN  NaN   NaN    NaN     NaN       NaN
# 1224906  NaN   NaN  ...  NaN  NaN  NaN   NaN    NaN     NaN       NaN
# 1224907  NaN   NaN  ...  NaN  NaN  NaN   NaN    NaN     NaN       NaN
# 1224908  NaN   NaN  ...  NaN  NaN  NaN   NaN    NaN     NaN       NaN
#
#         QTVEGETAUX ECOULEMENT QECOULEMENT
# 0              NaN        NaN         NaN
# 1              NaN        NaN         NaN
# 2              NaN        NaN         NaN
# 3              NaN        NaN         NaN
# 4              NaN        NaN         NaN
# ...            ...        ...         ...
# 1224904        NaN        NaN         NaN
# 1224905        NaN        NaN         NaN
# 1224906        NaN        NaN         NaN
# 1224907        NaN        NaN         NaN
# 1224908        NaN        NaN         NaN
#
# [1224909 rows x 204 columns]

# %% [markdown]
# ### Description des features

# %% [markdown]
# - `AAAAMMJJHH`  : date de la mesure (année mois jour heure)
# - RR1         : quantité de précipitation tombée en 1 heure (en mm et 1/10)
# - FF          : force du vent moyenné sur 10 mn, mesurée à 10 m (en m/s et 1/10)
# - FXY         : valeur maximale de FF dans l'heure (en m/s et 1/10)
# - FXI         : force maximale du vent instantané dans l'heure, mesurée à 10 m (en m/s et 1/10)
# - T           : température sous abri instantanée (en °C et 1/10)
# - TN          : température minimale sous abri dans l'heure (en °C et 1/10)
# - TX          : température maximale sous abri dans l'heure (en °C et 1/10)
# - U           : humidité relative (en %)
# - UN          : humidité relative minimale dans l'heure (en %)
# - UX          : humidité relative maximale dans l'heure (en %)
# - LAT         : latitude
# - LONG        : longitude

# %% [markdown]
# ### Nettoyage

# %%
df_weather['AAAAMMJJHH'] = pd.to_datetime(df_weather['AAAAMMJJHH'], format='%Y%m%d%H')

# %%
weather_features = [
    'T', 'TN', 'TX', 'U', 'UN', 'UX', 'FF', 'FXY', 'FXI', 'RR1','LAT','LON'
]

# %%
df_weather = df_weather[['AAAAMMJJHH'] + weather_features]

# %%
df_weather
# Out:
#                  AAAAMMJJHH    T   TN   TX    U   UN   UX   FF  FXY  FXI  RR1  \
# 0       2010-12-01 06:00:00  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1       2010-12-02 06:00:00  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2       2010-12-03 06:00:00  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3       2010-12-04 06:00:00  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4       2010-12-05 06:00:00  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 1224904 2023-12-31 19:00:00  9.4  9.4  9.7  NaN  NaN  NaN  NaN  NaN  NaN  0.0
# 1224905 2023-12-31 20:00:00  8.7  8.7  9.4  NaN  NaN  NaN  NaN  NaN  NaN  0.0
# 1224906 2023-12-31 21:00:00  8.4  8.4  8.7  NaN  NaN  NaN  NaN  NaN  NaN  0.0
# 1224907 2023-12-31 22:00:00  8.1  8.0  8.4  NaN  NaN  NaN  NaN  NaN  NaN  0.0
# 1224908 2023-12-31 23:00:00  7.8  7.8  8.1  NaN  NaN  NaN  NaN  NaN  NaN  0.0
#
#                LAT       LON
# 0        49.834000  4.200500
# 1        49.834000  4.200500
# 2        49.834000  4.200500
# 3        49.834000  4.200500
# 4        49.834000  4.200500
# ...            ...       ...
# 1224904  49.663833  3.320667
# 1224905  49.663833  3.320667
# 1224906  49.663833  3.320667
# 1224907  49.663833  3.320667
# 1224908  49.663833  3.320667
#
# [1224909 rows x 13 columns]

# %%
df_weather = df_weather.dropna(subset=set(weather_features))
df_weather
# Out:
#                  AAAAMMJJHH    T    TN   TX   U  UN  UX   FF   FXY   FXI  RR1  \
# 122     2010-01-01 00:00:00  0.6   0.5  0.7  94  92  94  4.0   4.4   6.2  0.0
# 123     2010-01-01 01:00:00  0.5   0.4  0.6  93  93  95  4.3   4.7   6.5  0.0
# 124     2010-01-01 02:00:00  0.2   0.2  0.5  94  92  94  4.1   4.8   6.7  0.0
# 125     2010-01-01 03:00:00  0.0   0.0  0.3  95  94  95  4.2   5.3   7.4  0.0
# 126     2010-01-01 04:00:00  0.0  -0.1  0.0  93  93  95  4.3   4.7   7.0  0.0
# ...                     ...  ...   ...  ...  ..  ..  ..  ...   ...   ...  ...
# 1196379 2023-12-31 19:00:00  8.8   8.6  8.9  71  70  72  8.9  10.6  14.7  0.0
# 1196380 2023-12-31 20:00:00  8.7   8.7  9.0  70  69  71  6.8   9.1  13.9  0.0
# 1196381 2023-12-31 21:00:00  8.2   8.2  9.0  72  70  73  6.3   7.4  12.0  0.0
# 1196382 2023-12-31 22:00:00  7.4   7.3  8.3  77  72  77  8.6   8.8  13.1  0.0
# 1196383 2023-12-31 23:00:00  7.2   7.1  7.4  78  77  79  7.6   9.5  14.6  0.0
#
#                LAT       LON
# 122      49.595667  3.610333
# 123      49.595667  3.610333
# 124      49.595667  3.610333
# 125      49.595667  3.610333
# 126      49.595667  3.610333
# ...            ...       ...
# 1196379  49.566000  4.036500
# 1196380  49.566000  4.036500
# 1196381  49.566000  4.036500
# 1196382  49.566000  4.036500
# 1196383  49.566000  4.036500
#
# [847927 rows x 13 columns]

# %%
df_weather = df_weather.rename(columns={'AAAAMMJJHH': 'DateTime'})

# %%
df_weather.dtypes
# Out:
# DateTime    datetime64[ns]
# T                   object
# TN                  object
# TX                  object
# U                   object
# UN                  object
# UX                  object
# FF                  object
# FXY                 object
# FXI                 object
# RR1                 object
# LAT                 object
# LON                 object
# dtype: object

# %%
# Liste des colonnes à convertir en float (en divisant par 10 quand nécessaire)
cols_to_convert = ['T', 'TN', 'TX', 'U', 'UN', 'UX', 'FF', 'FXY', 'FXI', 'RR1']

# Conversion sécurisée (valeurs invalides → NaN) puis division par 10 quand applicable
for col in cols_to_convert:
    df_weather[col] = pd.to_numeric(df_weather[col], errors='coerce')
df_weather
# Out:
#                    DateTime    T   TN   TX   U  UN  UX   FF   FXY   FXI  RR1  \
# 122     2010-01-01 00:00:00  0.6  0.5  0.7  94  92  94  4.0   4.4   6.2  0.0
# 123     2010-01-01 01:00:00  0.5  0.4  0.6  93  93  95  4.3   4.7   6.5  0.0
# 124     2010-01-01 02:00:00  0.2  0.2  0.5  94  92  94  4.1   4.8   6.7  0.0
# 125     2010-01-01 03:00:00  0.0  0.0  0.3  95  94  95  4.2   5.3   7.4  0.0
# 126     2010-01-01 04:00:00  0.0 -0.1  0.0  93  93  95  4.3   4.7   7.0  0.0
# ...                     ...  ...  ...  ...  ..  ..  ..  ...   ...   ...  ...
# 1196379 2023-12-31 19:00:00  8.8  8.6  8.9  71  70  72  8.9  10.6  14.7  0.0
# 1196380 2023-12-31 20:00:00  8.7  8.7  9.0  70  69  71  6.8   9.1  13.9  0.0
# 1196381 2023-12-31 21:00:00  8.2  8.2  9.0  72  70  73  6.3   7.4  12.0  0.0
# 1196382 2023-12-31 22:00:00  7.4  7.3  8.3  77  72  77  8.6   8.8  13.1  0.0
# 1196383 2023-12-31 23:00:00  7.2  7.1  7.4  78  77  79  7.6   9.5  14.6  0.0
#
#                LAT       LON
# 122      49.595667  3.610333
# 123      49.595667  3.610333
# 124      49.595667  3.610333
# 125      49.595667  3.610333
# 126      49.595667  3.610333
# ...            ...       ...
# 1196379  49.566000  4.036500
# 1196380  49.566000  4.036500
# 1196381  49.566000  4.036500
# 1196382  49.566000  4.036500
# 1196383  49.566000  4.036500
#
# [847927 rows x 13 columns]

# %%
# Diviser par 10 pour les colonnes concernées
cols_div10 = ['T', 'TN', 'TX', 'FF', 'FXY', 'FXI', 'RR1']
df_weather[cols_div10] = df_weather[cols_div10] / 10

# %%
df_weather
# Out:
#                    DateTime     T    TN    TX   U  UN  UX    FF   FXY   FXI  \
# 122     2010-01-01 00:00:00  0.06  0.05  0.07  94  92  94  0.40  0.44  0.62
# 123     2010-01-01 01:00:00  0.05  0.04  0.06  93  93  95  0.43  0.47  0.65
# 124     2010-01-01 02:00:00  0.02  0.02  0.05  94  92  94  0.41  0.48  0.67
# 125     2010-01-01 03:00:00  0.00  0.00  0.03  95  94  95  0.42  0.53  0.74
# 126     2010-01-01 04:00:00  0.00 -0.01  0.00  93  93  95  0.43  0.47  0.70
# ...                     ...   ...   ...   ...  ..  ..  ..   ...   ...   ...
# 1196379 2023-12-31 19:00:00  0.88  0.86  0.89  71  70  72  0.89  1.06  1.47
# 1196380 2023-12-31 20:00:00  0.87  0.87  0.90  70  69  71  0.68  0.91  1.39
# 1196381 2023-12-31 21:00:00  0.82  0.82  0.90  72  70  73  0.63  0.74  1.20
# 1196382 2023-12-31 22:00:00  0.74  0.73  0.83  77  72  77  0.86  0.88  1.31
# 1196383 2023-12-31 23:00:00  0.72  0.71  0.74  78  77  79  0.76  0.95  1.46
#
#          RR1        LAT       LON
# 122      0.0  49.595667  3.610333
# 123      0.0  49.595667  3.610333
# 124      0.0  49.595667  3.610333
# 125      0.0  49.595667  3.610333
# 126      0.0  49.595667  3.610333
# ...      ...        ...       ...
# 1196379  0.0  49.566000  4.036500
# 1196380  0.0  49.566000  4.036500
# 1196381  0.0  49.566000  4.036500
# 1196382  0.0  49.566000  4.036500
# 1196383  0.0  49.566000  4.036500
#
# [847927 rows x 13 columns]
